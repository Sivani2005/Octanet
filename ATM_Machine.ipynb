# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivani2005/Octanet/blob/main/ATM_Machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

time.sleep(3)

class ATM:
    def __init__(self):
       self.balance = 10000
       self.transaction_history = []

    def check_balance(self):
        print(f"Your balance is: {self.balance}/-")

    def deposit(self, amount):
        self.balance += amount
        self.transaction_history.append(f"Deposited {amount}/-")
        print( amount,"/-", "deposited successfully.")
        self.check_balance()

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
            self.transaction_history.append(f"Withdrew {amount}/-")
            print(amount,"/-", "withdrawn successfully.")
            self.check_balance()
        else:
            print("Insufficient funds!")

    def transfer(self, amount, recipient):
        if self.balance >= amount:
            self.balance -= amount
            self.transaction_history.append(f"Transferred {amount} /- to {recipient}")
            print( amount,"/-", "transferred successfully to", recipient)
            self.check_balance()
        else:
            print("Insufficient funds!")

    def print_transaction_history(self):
        print("Transaction History:")
        for transaction in self.transaction_history:
            print(transaction)


def main():
    atm = ATM()

    while True:
        print("\n**** ATM Menu ****")
        print("1. Check Balance")
        print("2. Deposit")
        print("3. Withdraw")
        print("4. Transfer")
        print("5. Transaction History")
        print("6. Quit")
        choice = int(input("Enter your choice (1-6): "))

        if choice == 1:
            atm.check_balance()
        elif choice == 2:
            amount = float(input("Enter amount to deposit: Rs"))
            atm.deposit(amount)
        elif choice == 3:
            amount = float(input("Enter amount to withdraw: Rs"))
            atm.withdraw(amount)
        elif choice == 4:
            amount = float(input("Enter amount to transfer: Rs"))
            recipient = input("Enter recipient's name: ")
            atm.transfer(amount, recipient)
        elif choice == 5:
            atm.print_transaction_history()
        elif choice == 6:
            print("Thank you for using our ATM. Have a great day!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 6.")

if __name__ == "__main__":
    main()
# Out:
# **** ATM Menu ****
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Transfer
# 5. Transaction History
# 6. Quit
# Enter your choice (1-6): 1
# Your balance is: 10000/-
#
# **** ATM Menu ****
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Transfer
# 5. Transaction History
# 6. Quit
# Enter your choice (1-6): 3000
# Invalid choice. Please enter a number between 1 and 6.
#
# **** ATM Menu ****
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Transfer
# 5. Transaction History
# 6. Quit
# Enter your choice (1-6): 2
# Enter amount to deposit: Rs3000
# 3000.0 /- deposited successfully.
# Your balance is: 13000.0/-
#
# **** ATM Menu ****
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Transfer
# 5. Transaction History
# 6. Quit
# Enter your choice (1-6): 3
# Enter amount to withdraw: Rs5000
# 5000.0 /- withdrawn successfully.
# Your balance is: 8000.0/-
#
# **** ATM Menu ****
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Transfer
# 5. Transaction History
# 6. Quit
# ...
